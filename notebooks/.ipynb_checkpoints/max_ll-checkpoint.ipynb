# %%
from __future__ import print_function
from datetime import datetime
import pandas
import numpy

# %%
import sys
sys.path.append('../shifted_beta_survival/')

# %%
from DataHandler import DataHandler
from ShiftedBeta import ShiftedBeta
from ShiftedBetaSurvival import ShiftedBetaSurvival

# %%
from new_test import make_raw_article_data, print_stats

# %%
data = pandas.read_csv('../data/data_2yr.csv')

total_size = 500
index = numpy.arange(data.shape[0])
numpy.random.shuffle(index)
index = index[:total_size]

data = data.iloc[index]
data.index = numpy.arange(total_size)

# %%
names = list(data.keys())[1:-2]

x = data[names].values
y = data.values[:, -2].astype(int)
z = data.values[:, -1].astype(int)

names = ['bias'] + names

# %%
sb = ShiftedBeta(verbose=True, gamma_alpha=1e1, gamma_beta=1e1)
sb.fit(y, z, x, restarts=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-693091c9df90> in <module>()
#       1 sb = ShiftedBeta(verbose=True, gamma_alpha=1e1, gamma_beta=1e1)
# ----> 2 sb.fit(y, z, x, restarts=1)
#
# /Users/fnogueira/Dropbox/Python_projects/beta-survival/shifted_beta_survival/ShiftedBeta.py in fit(self, age, alive, X, restarts)
#     217                                                          'Time',
#     218                                                          'LogLikelihood',
# --> 219                                                          print_space))
#     220             print("-"*35)
#     221
#
# /usr/local/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     425     elif meth == 'l-bfgs-b':
#     426         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 427                                 callback=callback, **options)
#     428     elif meth == 'tnc':
#     429         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /usr/local/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, **unknown_options)
#     313                 # minimization routine wants f and g at the current x
#     314                 # Overwrite f and g:
# --> 315                 f, g = func_and_grad(x)
#     316         elif task_str.startswith(b'NEW_X'):
#     317             # new iteration
#
# /usr/local/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     260         def func_and_grad(x):
#     261             f = fun(x, *args)
# --> 262             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     263             return f, g
#     264     else:
#
# /usr/local/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     554         ei[k] = 1.0
#     555         d = epsilon * ei
# --> 556         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     557         ei[k] = 0.0
#     558     return grad
#
# /usr/local/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     280     def function_wrapper(*wrapper_args):
#     281         ncalls[0] += 1
# --> 282         return function(*(wrapper_args + args))
#     283
#     284     return ncalls, function_wrapper
#
# /Users/fnogueira/Dropbox/Python_projects/beta-survival/shifted_beta_survival/ShiftedBeta.py in <lambda>(p)
#     215             print()
#     216             print("{0:^{3}} | {1:^10} | {2:13} |".format('Step',
# --> 217                                                          'Time',
#     218                                                          'LogLikelihood',
#     219                                                          print_space))
#
# /Users/fnogueira/Dropbox/Python_projects/beta-survival/shifted_beta_survival/ShiftedBeta.py in _logp(self, X, age, alive, wa, wb)
#     173
#     174             # add contribution of current customer to likelihood
# --> 175             log_like += numpy.log(self._recursive_retention_stats(a, b, y)[z])
#     176
#     177         # Negative log_like since we will use scipy's minimize object.
#
# KeyboardInterrupt:

# %%
print_stats(sb.alpha, sb.beta, [0], names)
for i in range(1, len(names)):
    print_stats(sb.alpha, sb.beta, [0, i], names)

# %%
preds_coeff = sb.predict(x)
preds = data[['system_key']].copy()
preds['alpha'] = preds_coeff[:, 0]
preds['beta'] = preds_coeff[:, 1]
preds['churn'] = preds_coeff[:, 0] / (preds_coeff[:, 0] + preds_coeff[:, 1])

print(x[:20])
print(preds.iloc[:20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-de02f287b215> in <module>()
# ----> 1 preds_coeff = sb.predict(x)
#       2 preds = data[['system_key']].copy()
#       3 preds['alpha'] = preds_coeff[:, 0]
#       4 preds['beta'] = preds_coeff[:, 1]
#       5 preds['churn'] = preds_coeff[:, 0] / (preds_coeff[:, 0] + preds_coeff[:, 1])
#
# NameError: name 'sb' is not defined

# %%
data.merge(preds, on='system_key').groupby('is_contractor').mean()[['churn']]
# Out:
#                   churn
# is_contractor
# 0              0.033909
# 1              0.029296

# %%
preds
# Out:
#        system_key     alpha       beta     churn
# 0          359159  0.918744  22.436072  0.039339
# 1          826716  0.581866  17.305559  0.032529
# 2          783875  0.918744  22.436072  0.039339
# 3         1543315  0.709807  80.715234  0.008717
# 4         1083580  0.918744  22.436072  0.039339
# 5          472560  0.918744  22.436072  0.039339
# 6         1182744  0.709807  80.715234  0.008717
# 7          701410  0.918744  22.436072  0.039339
# 8          547422  0.918744  22.436072  0.039339
# 9          925671  0.899522  17.694847  0.048376
# 10         844252  0.709807  80.715234  0.008717
# 11        1247248  0.918744  22.436072  0.039339
# 12         963393  0.918744  22.436072  0.039339
# 13        1351967  0.918744  22.436072  0.039339
# 14         730891  0.918744  22.436072  0.039339
# 15         681741  0.918744  22.436072  0.039339
# 16         965223  0.581866  17.305559  0.032529
# 17         826820  0.581866  17.305559  0.032529
# 18        1135651  0.918744  22.436072  0.039339
# 19        1535303  0.581866  17.305559  0.032529
# 20         703504  0.918744  22.436072  0.039339
# 21         378527  0.918744  22.436072  0.039339
# 22         950125  0.709807  80.715234  0.008717
# 23         696377  0.532232  71.633245  0.007375
# 24        1059761  0.918744  22.436072  0.039339
# 25         983032  0.918744  22.436072  0.039339
# 26         839769  0.918744  22.436072  0.039339
# 27        1400445  0.581866  17.305559  0.032529
# 28        1420382  0.918744  22.436072  0.039339
# 29         746381  0.918744  22.436072  0.039339
